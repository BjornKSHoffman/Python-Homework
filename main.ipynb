445709,
712961,
-1163797,
569899,
768450,
102685,
795914,
60988,
138230,
671099,
]


###### list and dict manipulation
# Iterate over key-value pairs in the Dict
for date, profit_loss in budget_data.items():
    print(f"Date: {date} | profit_loss: {profit_loss}")

# Iterate over key-value pairs in the Dict but print only half to extract a list from the dict, print with a comma afterward too, then insert above
for date, profit_loss in budget_data.items():
    print(f"{profit_loss},")
    

#########


#The total number of months included in the dataset
print(len(budget_data))

#The net total amount of Profit/Losses over the entire period.
    

# Calculate sum of profit/loss by cumulatively summing up the total profits/losses and count of trading days
total_profit_loss = sum(profit_loss_list)

print(f"total_profit_loss: {total_profit_loss}")


#The average of the changes in Profit/Losses over the entire period
# Calculate average Profit/Losses of banks in the dictionary
avg_change_profit_loss = round(total_profit_loss / (len(budget_data)), 2)

print(f"avg_change_profit_loss : {avg_change_profit_loss}")


#The greatest increase in profits (date and amount) over the entire period.

# Initialize the metric variables
count = 0
total = 0
average = 0
minimum = 0
maximum = 0

# Iterate over each profit_loss the list
for indiv_profit_loss in profit_loss_list:
    
 # Cumulatively sum up the total profits/losses and count of trading days
    total = total + indiv_profit_loss
    count += 1
    
# Logic to determine minimum and maximum values
    if minimum == 0:
        minimum = indiv_profit_loss
    elif indiv_profit_loss < minimum:
        minimum = indiv_profit_loss
    elif indiv_profit_loss > maximum:
        maximum = indiv_profit_loss

print(f"minimum: {minimum}")
print(f"maximum: {maximum}")
print(f"count: {count}")

#locate date of greatest increase in original dict  -- I think this didn't work because PANDAS wasn't imported, so I hashed it out and found the date manually below
 #budget_data.loc({maximum})
#locate date of greatest decrease in original dict -- see above
 #budget_data.loc({minimum})

print(f"Financial Analysis: Total Months: " + {count}  + "Total: $" + {total_profit_loss} + "Average  Change: $ " + {avg_change_profit_loss} + "Greatest Increase in Profits: Feb-2012 " + {maximum}, + "Greatest Decrease in Profits: Sep-2013 " + {minimum})
# Out:
# Date: Jan-2010 | profit_loss: 867884
# Date: Feb-2010 | profit_loss: 984655
# Date: Mar-2010 | profit_loss: 322013
# Date: Apr-2010 | profit_loss: -69417
# Date: May-2010 | profit_loss: 310503
# Date: Jun-2010 | profit_loss: 522857
# Date: Jul-2010 | profit_loss: 1033096
# Date: Aug-2010 | profit_loss: 604885
# Date: Sep-2010 | profit_loss: -216386
# Date: Oct-2010 | profit_loss: 477532
# Date: Nov-2010 | profit_loss: 893810
# Date: Dec-2010 | profit_loss: -80353
# Date: Jan-2011 | profit_loss: 779806
# Date: Feb-2011 | profit_loss: -335203
# Date: Mar-2011 | profit_loss: 697845
# Date: Apr-2011 | profit_loss: 793163
# Date: May-2011 | profit_loss: 485070
# Date: Jun-2011 | profit_loss: 584122
# Date: Jul-2011 | profit_loss: 62729
# Date: Aug-2011 | profit_loss: 668179
# Date: Sep-2011 | profit_loss: 899906
# Date: Oct-2011 | profit_loss: 834719
# Date: Nov-2011 | profit_loss: 132003
# Date: Dec-2011 | profit_loss: 309978
# Date: Jan-2012 | profit_loss: -755566
# ...
